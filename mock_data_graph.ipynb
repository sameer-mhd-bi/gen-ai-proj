# %%
import json
import pandas as pd
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Create the Synthetic Fraud Ring Dataset
fraud_ring_data = [
    {
        "customer_id": "CUST_001",
        "full_name": "James Sterling",
        "email": "j.sterling@mailnet.com",
        "phone": "+91 98765 43210",
        "address": "42, Green Glen Layout, Bellandur, Bengaluru",
        "device_id": "DEV_A98X77",
        "bank_account": "ACC_991823"
    },
    {
        "customer_id": "CUST_002",
        "full_name": "Anita Rao",
        "email": "anita.r.1990@webmail.in",
        "phone": "+91 91234 56789",
        "address": "15, Park Street, Sector 2, Salt Lake, Kolkata",
        "device_id": "DEV_B44Z11",
        "bank_account": "ACC_445122"
    },
    {
        "customer_id": "CUST_003",
        "full_name": "Jamie Sterling", # Fraud Ring Entity 1: Name variation & shared address/device with CUST_001
        "email": "admin@opssecure.net",
        "phone": "+91 98765 43211",
        "address": "42, Green Glen Layout, Bellandur, Bengaluru",
        "device_id": "DEV_A98X77",
        "bank_account": "ACC_991823"
    },
    {
        "customer_id": "CUST_004",
        "full_name": "Vikram Malhotra",
        "email": "v.malhotra@mailnet.com",
        "phone": "+91 88888 77777",
        "address": "78, Phase 3, Hitech City, Hyderabad",
        "device_id": "DEV_C55M99",
        "bank_account": "ACC_112233"
    },
    {
        "customer_id": "CUST_005",
        "full_name": "Siddharth Shah", # Fraud Ring Entity 2: Shared email & device with CUST_003
        "email": "admin@opssecure.net",
        "phone": "+91 77777 66666",
        "address": "Suite 401, Tech Park Towers, Whitefield, Bengaluru",
        "device_id": "DEV_A98X77",
        "bank_account": "ACC_556677"
    }
]

# 2. Save the dataset to a JSON file for your records
json_filename = "dummy_customers.json"
with open(json_filename, "w") as f:
    json.dump(fraud_ring_data, f, indent=4)
print(f"Data saved to {json_filename}")

# 3. Generate the Structured PDF
pdf_filename = "customer_profiles_for_extraction.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=30, leftMargin=30, topMargin=30, bottomMargin=30)
story = []

# Styles setup
styles = getSampleStyleSheet()
title_style = ParagraphStyle(
    'DocTitle', 
    parent=styles['Heading1'], 
    fontSize=22, 
    textColor=colors.HexColor("#1A365D"), 
    spaceAfter=15
)
section_heading = ParagraphStyle(
    'SectionHead', 
    parent=styles['Heading2'], 
    fontSize=13, 
    textColor=colors.HexColor("#2B6CB0"), 
    spaceBefore=10, 
    spaceAfter=6
)
body_style = ParagraphStyle(
    'TableBody', 
    parent=styles['BodyText'], 
    fontSize=10, 
    leading=12
)

# Document Header
story.append(Paragraph("Master Customer Application Directory", title_style))
story.append(Paragraph("Confidential Internal Audit Records for Knowledge Graph Parsing.", styles['Italic']))
story.append(Spacer(1, 15))

# Loop through records and structure them as isolated text profiles for NLP
for customer in fraud_ring_data:
    story.append(Paragraph(f"Customer Record: {customer['customer_id']}", section_heading))
    
    # Formulate unstructured text sentences that spaCy can extract triples from
    profile_text = (
        f"The applicant <b>{customer['full_name']}</b> registered account <b>{customer['customer_id']}</b>. "
        f"The individual resides at the primary address <b>{customer['address']}</b>. "
        f"They verified ownership of the phone number <b>{customer['phone']}</b> and utilize the email address <b>{customer['email']}</b>. "
        f"System logs indicate the user initiated registration from device <b>{customer['device_id']}</b> and linked external bank account <b>{customer['bank_account']}</b>."
    )
    
    story.append(Paragraph(profile_text, body_style))
    story.append(Spacer(1, 8))
    
    # Optional: Tabular summary to verify extraction ground truth visually
    table_data = [
        [Paragraph(f"<b>Field</b>", body_style), Paragraph(f"<b>Value</b>", body_style)],
        ["Name", customer['full_name']],
        ["Address", customer['address']],
        ["Email", customer['email']],
        ["Device Linked", customer['device_id']],
        ["Bank Account", customer['bank_account']]
    ]
    
    t = Table(table_data, colWidths=[100, 440])
    t.setStyle(TableStyle([
        ('BACKGROUND', (0,0), (1,0), colors.HexColor("#E2E8F0")),
        ('GRID', (0,0), (-1,-1), 0.5, colors.HexColor("#CBD5E0")),
        ('PADDING', (0,0), (-1,-1), 4),
        ('FONTSIZE', (0,0), (-1,-1), 9),
        ('VALIGN', (0,0), (-1,-1), 'MIDDLE'),
    ]))
    story.append(t)
    story.append(Spacer(1, 15))

# Build PDF
doc.build(story)
print(f"PDF successfully generated at: {pdf_filename}")
# Out:
# Data saved to dummy_customers.json
# PDF successfully generated at: customer_profiles_for_extraction.pdf

# %%
pip install pandas reportlab
# Out:
# ...
#   Using cached pillow-12.2.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.0 MB 2.0 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.3/2.0 MB 3.5 MB/s eta 0:00:01
#    --------- ------------------------------ 0.5/2.0 MB 3.7 MB/s eta 0:00:01
#    -------------- ------------------------- 0.7/2.0 MB 3.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.8/2.0 MB 3.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.8/2.0 MB 3.4 MB/s eta 0:00:01
#    -------------------- ------------------- 1.0/2.0 MB 3.2 MB/s eta 0:00:01
#    ------------------------ --------------- 1.2/2.0 MB 3.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.4/2.0 MB 3.4 MB/s eta 0:00:01
#    -------------------------------- ------- 1.6/2.0 MB 3.5 MB/s eta 0:00:01
# ...

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Clear Fraud Dataset with Blatant Overlaps
fraud_ring_data = [
    {
        "customer": "James Sterling",
        "account": "CUST_001",
        "address": "Bellandur Bengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Anita Rao",
        "account": "CUST_002",
        "address": "Salt Lake Kolkata",
        "device": "DEV_B44Z11"
    },
    {
        "customer": "Jamie Sterling", # Fake identity matching CUST_001
        "account": "CUST_003",
        "address": "Bellandur Bengaluru", # Explicit Link 1
        "device": "DEV_A98X77"            # Explicit Link 2
    },
    {
        "customer": "Siddharth Shah", # Another identity matching CUST_001 & 003
        "account": "CUST_005",
        "address": "Whitefield Bengaluru",
        "device": "DEV_A98X77"            # Explicit Link 3 (The Ring Anchor)
    }
]

# Generate explicit NLP-friendly PDF
pdf_filename = "fraud_ring_extraction_file.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=20, textColor=colors.HexColor("#1A365D"), spaceAfter=20)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16, spaceAfter=12)

story.append(Paragraph("Customer Account Registration Logs", title_style))
story.append(Spacer(1, 10))

# We use strict "Entity-Verb-Entity" structures so your spaCy triple extractor succeeds perfectly.
# for row in fraud_ring_data:
#     narrative = (
#         f"<b>{row['customer']}</b> registered account <b>{row['account']}</b>. <br/>"
#         f"The account <b>{row['account']}</b> uses address <b>{row['address']}</b>. <br/>"
#         f"The account <b>{row['account']}</b> linked device <b>{row['device']}</b>."
#     )
#     story.append(Paragraph(narrative, body_style))
#     story.append(Spacer(1, 10))

for row in fraud_ring_data:
    # Using a single unified string format for the address value
    unified_address = f"Location-{row['address'].replace(' ', '')}" 
    
    narrative = (
        f"User {row['customer']} owns {row['account']}. <br/>"
        f"{row['account']} uses {unified_address}. <br/>"
        f"{row['account']} linked {row['device']}."
    )
    story.append(Paragraph(narrative, body_style))


doc.build(story)
print(f"PDF compiled successfully at: {pdf_filename}")
# Out:
# PDF compiled successfully at: fraud_ring_extraction_file.pdf

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Base Profiles with Overlapping Hardware/Addresses
fraud_ring_data = [
    {
        "customer": "James Sterling",
        "account": "CUST_001",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Anita Rao",
        "account": "CUST_002",
        "address": "SaltLakeKolkata",
        "device": "DEV_B44Z11"
    },
    {
        "customer": "Jamie Sterling",
        "account": "CUST_003",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Siddharth Shah",
        "account": "CUST_005",
        "address": "WhitefieldBengaluru",
        "device": "DEV_A98X77"
    }
]

# 2. Circular Transaction Matrix (Money Laundering Loop)
# Legitimate user (CUST_002) is excluded to keep them isolated in the graph.
transaction_data = [
    {"source": "CUST_001", "action": "transferredFundsTo", "destination": "CUST_005"},
    {"source": "CUST_005", "action": "transferredFundsTo", "destination": "CUST_003"},
    {"source": "CUST_003", "action": "transferredFundsTo", "destination": "CUST_001"}
]

# Generate the comprehensive PDF
pdf_filename = "money_laundering_loop_dataset.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=18, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
section_style = ParagraphStyle('Section', parent=styles['Heading2'], fontSize=13, textColor=colors.HexColor("#2B6CB0"), spaceBefore=12, spaceAfter=8)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16, spaceAfter=10)

# Section 1: Customer Profile Configurations
story.append(Paragraph("Part 1: Master Customer Profile Logs", title_style))
story.append(Spacer(1, 5))

for row in fraud_ring_data:
    profile_narrative = (
        f"User {row['customer']} owns {row['account']}. <br/>"
        f"{row['account']} uses {row['address']}. <br/>"
        f"{row['account']} linked {row['device']}."
    )
    story.append(Paragraph(profile_narrative, body_style))

story.append(Spacer(1, 15))

# Section 2: Financial Inter-Account Ledger
story.append(Paragraph("Part 2: Inter-Account Transaction Ledger", section_style))
story.append(Spacer(1, 5))

for tx in transaction_data:
    # Direct Subject-Verb-Object string optimized for SpaCy dependency matching
    tx_narrative = f"Account {tx['source']} {tx['action']} account {tx['destination']}."
    story.append(Paragraph(tx_narrative, body_style))

doc.build(story)
print(f"PDF compiled successfully with transaction loop at: {pdf_filename}")
# Out:
# PDF compiled successfully with transaction loop at: money_laundering_loop_dataset.pdf

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Base Profiles
fraud_ring_data = [
    {
        "customer": "James Sterling",
        "account": "CUST_001",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Anita Rao",
        "account": "CUST_002",
        "address": "SaltLakeKolkata",
        "device": "DEV_B44Z11"
    },
    {
        "customer": "Jamie Sterling",
        "account": "CUST_003",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Siddharth Shah",
        "account": "CUST_005",
        "address": "WhitefieldBengaluru",
        "device": "DEV_A98X77"
    }
]

# 2. Velocity Loop Matrix (Rapid money movement within minutes)
# Formatted with explicit 'atTime' and 'withAmount' tokens for strict entity extraction
transaction_data = [
    {
        "source": "CUST_001", 
        "action": "transferredFundsTo", 
        "destination": "CUST_005", 
        "amount": "INR_500000", 
        "time": "Time_1430"
    },
    {
        "source": "CUST_005", 
        "action": "transferredFundsTo", 
        "destination": "CUST_003", 
        "amount": "INR_495000", # Slightly lower to simulate laundering fee skim
        "time": "Time_1437"      # Only 7 minutes later (High Velocity)
    },
    {
        "source": "CUST_003", 
        "action": "transferredFundsTo", 
        "destination": "CUST_001", 
        "amount": "INR_490000", 
        "time": "Time_1442"      # Only 5 minutes later (Loop complete)
    }
]

# Generate PDF Document
pdf_filename = "high_velocity_laundering_dataset.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=18, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
section_style = ParagraphStyle('Section', parent=styles['Heading2'], fontSize=13, textColor=colors.HexColor("#2B6CB0"), spaceBefore=12, spaceAfter=8)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16, spaceAfter=10)

# Render Profiles
story.append(Paragraph("Part 1: Account Registry Profiles", title_style))
for row in fraud_ring_data:
    profile_narrative = (
        f"User {row['customer']} owns {row['account']}. <br/>"
        f"{row['account']} uses {row['address']}. <br/>"
        f"{row['account']} linked {row['device']}."
    )
    story.append(Paragraph(profile_narrative, body_style))

story.append(Spacer(1, 15))

# Render Velocity Transactions
story.append(Paragraph("Part 2: Real-Time High-Velocity Ledger", section_style))
for tx in transaction_data:
    # Strict declarative syntax to protect spaCy's dependency parser from splitting attributes
    tx_narrative = (
        f"Account {tx['source']} {tx['action']} account {tx['destination']}. <br/>"
        f"The transaction processed amount {tx['amount']} at {tx['time']}."
    )
    story.append(Paragraph(tx_narrative, body_style))

doc.build(story)
print(f"PDF compiled successfully with transaction thresholds at: {pdf_filename}")
# Out:
# PDF compiled successfully with transaction thresholds at: high_velocity_laundering_dataset.pdf

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Base Profiles
fraud_ring_data = [
    {
        "customer": "James Sterling",
        "account": "CUST_001",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Anita Rao",
        "account": "CUST_002",
        "address": "SaltLakeKolkata",
        "device": "DEV_B44Z11"
    },
    {
        "customer": "Jamie Sterling",
        "account": "CUST_003",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Siddharth Shah",
        "account": "CUST_005",
        "address": "WhitefieldBengaluru",
        "device": "DEV_A98X77"
    }
]

# 2. Strict Subject-Predicate-Object Transactions for Chart Node Generation
transaction_data = [
    {
        "tx_id": "TX_901",
        "source": "CUST_001", 
        "destination": "CUST_005", 
        "amount": "INR_500000", 
        "time": "Time_1430"
    },
    {
        "tx_id": "TX_902",
        "source": "CUST_005", 
        "destination": "CUST_003", 
        "amount": "INR_495000", 
        "time": "Time_1437"
    },
    {
        "tx_id": "TX_903",
        "source": "CUST_003", 
        "destination": "CUST_001", 
        "amount": "INR_490000", 
        "time": "Time_1442"
    }
]

# Generate PDF Document
pdf_filename = "explicit_velocity_graph_dataset.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=18, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
section_style = ParagraphStyle('Section', parent=styles['Heading2'], fontSize=13, textColor=colors.HexColor("#2B6CB0"), spaceBefore=12, spaceAfter=8)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16, spaceAfter=10)

# Render Profiles
story.append(Paragraph("Part 1: Account Registry Profiles", title_style))
for row in fraud_ring_data:
    profile_narrative = (
        f"User {row['customer']} owns {row['account']}. <br/>"
        f"{row['account']} uses {row['address']}. <br/>"
        f"{row['account']} linked {row['device']}."
    )
    story.append(Paragraph(profile_narrative, body_style))

story.append(Spacer(1, 15))

# Render Transactions using hyper-strict relation formulas
story.append(Paragraph("Part 2: Real-Time High-Velocity Ledger", section_style))
for tx in transaction_data:
    # This explicit grammar forces spaCy to connect the Accounts to the Transfer Node,
    # and directly attaches the Amount and Time to that specific transaction event.
    tx_narrative = (
        f"Account {tx['source']} initiated {tx['tx_id']}. <br/>"
        f"The transaction {tx['tx_id']} targets account {tx['destination']}. <br/>"
        f"The transaction {tx['tx_id']} holds {tx['amount']}. <br/>"
        f"The transaction {tx['tx_id']} occurred at {tx['time']}."
    )
    story.append(Paragraph(tx_narrative, body_style))

doc.build(story)
print(f"PDF compiled successfully for direct chart injection at: {pdf_filename}")
# Out:
# PDF compiled successfully for direct chart injection at: explicit_velocity_graph_dataset.pdf

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Base Identity Configurations
fraud_ring_data = [
    {
        "customer": "James Sterling",
        "account": "CUST_001",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Anita Rao",
        "account": "CUST_002",
        "address": "SaltLakeKolkata",
        "device": "DEV_B44Z11"
    },
    {
        "customer": "Jamie Sterling",
        "account": "CUST_003",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Siddharth Shah",
        "account": "CUST_005",
        "address": "WhitefieldBengaluru",
        "device": "DEV_A98X77"
    }
]

# 2. Velocity Configuration mapped for Direct Pipeline Extraction
transaction_data = [
    {
        "tx_id": "TX_901",
        "source": "CUST_001", 
        "destination": "CUST_005", 
        "amount": "Amount_INR500000", # Connected alphanumeric string
        "time": "Timestamp_1430"
    },
    {
        "tx_id": "TX_902",
        "source": "CUST_005", 
        "destination": "CUST_003", 
        "amount": "Amount_INR495000", 
        "time": "Timestamp_1437"
    },
    {
        "tx_id": "TX_903",
        "source": "CUST_003", 
        "destination": "CUST_001", 
        "amount": "Amount_INR490000", 
        "time": "Timestamp_1442"
    }
]

# PDF Building Setup
pdf_filename = "fixed_inr_velocity_dataset.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=18, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
section_style = ParagraphStyle('Section', parent=styles['Heading2'], fontSize=13, textColor=colors.HexColor("#2B6CB0"), spaceBefore=12, spaceAfter=8)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16, spaceAfter=10)

# Build Registry
story.append(Paragraph("Part 1: Network Profile Registries", title_style))
for row in fraud_ring_data:
    profile_narrative = (
        f"User {row['customer']} owns {row['account']}. <br/>"
        f"{row['account']} uses {row['address']}. <br/>"
        f"{row['account']} linked {row['device']}."
    )
    story.append(Paragraph(profile_narrative, body_style))

story.append(Spacer(1, 15))

# Build High-Velocity Ledger with Fixed Alphanumeric Extraction Syntax
story.append(Paragraph("Part 2: Transaction Event Metrics", section_style))
for tx in transaction_data:
    # Direct Subject-Predicate-Object relations to establish explicit visual paths
    tx_narrative = (
        f"Account {tx['source']} deployed {tx['tx_id']}. <br/>"
        f"The transaction {tx['tx_id']} credited {tx['destination']}. <br/>"
        f"The transaction {tx['tx_id']} holds {tx['amount']}. <br/>"
        f"The transaction {tx['tx_id']} records {tx['time']}."
    )
    story.append(Paragraph(tx_narrative, body_style))

doc.build(story)
print(f"PDF compiled successfully with visible INR attributes: {pdf_filename}")
# Out:
# PDF compiled successfully with visible INR attributes: fixed_inr_velocity_dataset.pdf

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Base Profiles
fraud_ring_data = [
    {
        "customer": "James Sterling",
        "account": "CUST_001",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
    {
        "customer": "Anita Rao",
        "account": "CUST_002",
        "address": "SaltLakeKolkata",
        "device": "DEV_B44Z11"
    },
    {
        "customer": "Jamie Sterling",
        "account": "CUST_003",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X77"
    },
        {
        "customer": "Rohit Mishra",
        "account": "CUST_004",
        "address": "BellandurBengaluru",
        "device": "DEV_A98X79"
    },
    {
        "customer": "Siddharth Shah",
        "account": "CUST_005",
        "address": "WhitefieldBengaluru",
        "device": "DEV_A98X77"
    }
]

# 2. Closed Round-Trip Loop Matrix (CUST_001 -> CUST_005 -> CUST_003 -> CUST_001)
transaction_data = [
    {
        "tx_id": "TX_901",
        "source": "CUST_001",       # Loop Starts Here
        "destination": "CUST_005", 
        "amount": "Amount_INR500000", 
        "time": "Timestamp_1430"
    },
    {
        "tx_id": "TX_902",
        "source": "CUST_005", 
        "destination": "CUST_003", 
        "amount": "Amount_INR495000", 
        "time": "Timestamp_1437"
    },
    {
        "tx_id": "TX_903",
        "source": "CUST_003", 
        "destination": "CUST_001",   # Loop Closes Here (Returns to Originator)
        "amount": "Amount_INR490000", 
        "time": "Timestamp_1442"
    },
    {
        "tx_id": "TX_904",
        "source": "CUST_002", 
        "destination": "CUST_004",   # Loop Closes Here (Returns to Originator)
        "amount": "Amount_INR290000", 
        "time": "Timestamp_1448"
    }
]

# Generate PDF Document
pdf_filename = "closed_loop_laundering_dataset.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=18, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
section_style = ParagraphStyle('Section', parent=styles['Heading2'], fontSize=13, textColor=colors.HexColor("#2B6CB0"), spaceBefore=12, spaceAfter=8)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16, spaceAfter=10)

# Part 1: Identity Profile Logs
story.append(Paragraph("Part 1: Account Registry Profiles", title_style))
for row in fraud_ring_data:
    profile_narrative = (
        f"User {row['customer']} owns {row['account']}. <br/>"
        f"{row['account']} uses {row['address']}. <br/>"
        f"{row['account']} linked {row['device']}."
    )
    story.append(Paragraph(profile_narrative, body_style))

story.append(Spacer(1, 15))

# Build High-Velocity Ledger with Direct Subject Linking
story.append(Paragraph("Part 2: Circular Flow Ledger", section_style))
for tx in transaction_data:
    # We remove the word "transaction" or "account" to force spaCy 
    # to link the IDs directly to each other.
    tx_narrative = (
        f"{tx['source']} deployed {tx['tx_id']}. <br/>"
        f"{tx['tx_id']} credited {tx['destination']}. <br/>"
        f"{tx['tx_id']} holds {tx['amount']}. <br/>"
        f"{tx['tx_id']} records {tx['time']}."
    )
    story.append(Paragraph(tx_narrative, body_style))


doc.build(story)
print(f"PDF successfully generated with an unbroken closed loop at: {pdf_filename}")
# Out:
# PDF successfully generated with an unbroken closed loop at: closed_loop_laundering_dataset.pdf

# %%
from pptx import Presentation
from pptx.util import Inches, Pt
from pptx.enum.text import PP_ALIGN
from pptx.dml.color import RGBColor
from pptx.enum.shapes import MSO_SHAPE

# 1. Initialize presentation and set blank layout
prs = Presentation()
prs.slide_width = Inches(13.333) # 16:9 Widescreen aspect ratio
prs.slide_height = Inches(7.5)
blank_slide_layout = prs.slide_layouts[6]
slide = prs.slides.add_slide(blank_slide_layout)

# 2. Design System Colors
DARK_NAVY = RGBColor(0x1A, 0x36, 0x5D)
STEEL_BLUE = RGBColor(0x2B, 0x6C, 0xB0)
TEXT_CHARCOAL = RGBColor(0x2D, 0x37, 0x48)
BG_LIGHT_GRAY = RGBColor(0xF7, 0xFA, 0xFC)
BORDER_GRAY = RGBColor(0xE2, 0xE8, 0xF0)

# 3. Add Header Section
header_box = slide.shapes.add_textbox(Inches(0.75), Inches(0.5), Inches(11.833), Inches(1.2))
tf = header_box.text_frame
tf.word_wrap = True
p = tf.paragraphs[0]
p.text = "Unmasking Collusion: Detecting Insurance Fraud Rings"
p.font.size = Pt(32)
p.font.bold = True
p.font.color.rgb = DARK_NAVY
p.font.name = "Arial"

p2 = tf.add_paragraph()
p2.text = "How Knowledge Graphs transform unstructured claims data into proactive network intelligence."
p2.font.size = Pt(14)
p2.font.italic = True
p2.font.color.rgb = STEEL_BLUE
p2.font.name = "Arial"

# 4. Left Column: The Problem
left_box = slide.shapes.add_textbox(Inches(0.75), Inches(2.0), Inches(5.6), Inches(3.0))
tf_left = left_box.text_frame
tf_left.word_wrap = True

p_left_title = tf_left.paragraphs[0]
p_left_title.text = "THE INSURANCE FRAUD CHALLENGE"
p_left_title.font.size = Pt(14)
p_left_title.font.bold = True
p_left_title.font.color.rgb = STEEL_BLUE
p_left_title.space_after = Pt(10)

left_bullets = [
    "Hidden Connections: Bad actors exploit data silos by staging accidents across different insurers, vehicles, and coverage policies.",
    "The 'Mule' Disguise: Individual claims look completely legitimate when evaluated in isolation by traditional rules engines.",
    "Coordinated Networks: Organized rings systematically drain payouts using shared links like identical body shops or medical clinics."
]
for bullet in left_bullets:
    p_b = tf_left.add_paragraph()
    p_b.text = "• " + bullet
    p_b.font.size = Pt(12)
    p_b.font.color.rgb = TEXT_CHARCOAL
    p_b.space_after = Pt(6)

# 5. Right Column: The Solution
right_box = slide.shapes.add_textbox(Inches(6.983), Inches(2.0), Inches(5.6), Inches(3.0))
tf_right = right_box.text_frame
tf_right.word_wrap = True

p_right_title = tf_right.paragraphs[0]
p_right_title.text = "THE KNOWLEDGE GRAPH SOLUTION"
p_right_title.font.size = Pt(14)
p_right_title.font.bold = True
p_right_title.font.color.rgb = STEEL_BLUE
p_right_title.space_after = Pt(10)

right_bullets = [
    "Entity Resolution: Converts raw text (PDF reports, call logs, invoices) into interconnected Subject → Predicate → Object triples.",
    "Unified Network Analysis: Automatically links distinct policyholders if they share a digital footprint, device ID, or location.",
    "Pattern Recognition: Uncovers circular cash flows, phantom passengers, and recurring vendor relationships instantly."
]
for bullet in right_bullets:
    p_b = tf_right.add_paragraph()
    p_b.text = "• " + bullet
    p_b.font.size = Pt(12)
    p_b.font.color.rgb = TEXT_CHARCOAL
    p_b.space_after = Pt(6)

# 6. Bottom Component: Visualizing a Fraud Ring Pattern
# Add background card for diagram
shape = slide.shapes.add_shape(MSO_SHAPE.RECTANGLE, Inches(0.75), Inches(5.3), Inches(11.833), Inches(1.5))
shape.fill.solid()
shape.fill.fore_color.rgb = BG_LIGHT_GRAY
shape.line.color.rgb = BORDER_GRAY

# Add Diagram Content Text
diagram_box = slide.shapes.add_textbox(Inches(0.9), Inches(5.4), Inches(11.533), Inches(1.3))
tf_diag = diagram_box.text_frame
tf_diag.word_wrap = True

p_diag = tf_diag.paragraphs[0]
p_diag.alignment = PP_ALIGN.CENTER
p_diag.text = "[Claim 101] ──(Involves)──> [Policyholder A] ──(Uses Device)──> [HW_ID: 991X] <──(Uses Device)── [Policyholder B] ──(Involves)──> [Claim 102]"
p_diag.font.name = "Courier New"
p_diag.font.size = Pt(11)
p_diag.font.bold = True
p_diag.font.color.rgb = DARK_NAVY

p_diag_lbl = tf_diag.add_paragraph()
p_diag_lbl.alignment = PP_ALIGN.CENTER
p_diag_lbl.text = "💡 Value Impact: By connecting separate claim attributes into a single unified mesh, insurers intercept rings instead of single claims."
p_diag_lbl.font.name = "Arial"
p_diag_lbl.font.size = Pt(11)
p_diag_lbl.font.italic = True
p_diag_lbl.font.color.rgb = TEXT_CHARCOAL
p_diag_lbl.space_before = Pt(8)

# 7. Save file
prs.save("insurance_fraud_graph_slide.pptx")
print("Presentation slide generated successfully as 'insurance_fraud_graph_slide.pptx'.")
# Out:
# Presentation slide generated successfully as 'insurance_fraud_graph_slide.pptx'.

# %%
pip install python-pptx
# Out:
# ...
#   Using cached python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# ...
# Using cached python_pptx-1.0.2-py3-none-any.whl (472 kB)
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.0 MB 5.7 MB/s eta 0:00:01
#    ------ --------------------------------- 0.7/4.0 MB 6.9 MB/s eta 0:00:01
#    ------------ --------------------------- 1.2/4.0 MB 8.7 MB/s eta 0:00:01
#    --------------- ------------------------ 1.6/4.0 MB 8.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.3/4.0 MB 9.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.0/4.0 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 10.7 MB/s eta 0:00:00
# ...

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Insurance Fraud Ring Dataset Mapping Your Exact Diagram
insurance_fraud_data = [
    {
        "claim_id": "Claim_101",
        "policyholder": "Policyholder_A",
        "accident_date": "Date_12_March",
        "device": "HW_ID_991X",
        "claimed_amount": "Amount_INR_350000"
    },
    {
        "claim_id": "Claim_102",
        "policyholder": "Policyholder_B",
        "accident_date": "Date_14_March",
        "device": "HW_ID_991X", # Shared Ring Anchor
        "claimed_amount": "Amount_INR_420000"
    }
]

# 2. Build the PDF Document
pdf_filename = "insurance_fraud_demo_dataset.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

# Styles Setup
styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=18, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
section_style = ParagraphStyle('Section', parent=styles['Heading2'], fontSize=13, textColor=colors.HexColor("#2B6CB0"), spaceBefore=12, spaceAfter=8)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16, spaceAfter=10)

# Render Document Elements
story.append(Paragraph("Automated Insurance Claims Directory", title_style))
story.append(Paragraph("Internal Audit Intake Records for Knowledge Extraction.", styles['Italic']))
story.append(Spacer(1, 10))

story.append(Paragraph("Claims Processing Logs", section_style))

# Strict Subject-Predicate-Object sentences designed to link Claim -> Policyholder -> Device
for claim in insurance_fraud_data:
    narrative = (
        f"{claim['claim_id']} involves {claim['policyholder']}. <br/>"
        f"{claim['policyholder']} uses device {claim['device']}. <br/>"
        f"{claim['claim_id']} holds {claim['claimed_amount']}. <br/>"
        f"{claim['claim_id']} records {claim['accident_date']}."
    )
    story.append(Paragraph(narrative, body_style))
    story.append(Spacer(1, 10))

doc.build(story)
print(f"Insurance fraud demo PDF successfully compiled at: {pdf_filename}")
# Out:
# Insurance fraud demo PDF successfully compiled at: insurance_fraud_demo_dataset.pdf

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Insurance Fraud Ring Dataset Mapping Your Exact Diagram
insurance_fraud_data = [
    {
        "claim_id": "Claim_101",
        "policyholder": "Policyholder_A",
        "accident_date": "Date_12_March",
        "device": "HW_ID_991X",
        "claimed_amount": "Amount_INR_350000"
    },
    {
        "claim_id": "Claim_102",
        "policyholder": "Policyholder_B",
        "accident_date": "Date_14_March",
        "device": "HW_ID_991X", # Shared Ring Anchor
        "claimed_amount": "Amount_INR_420000"
    }
]

# 2. Build the PDF Document
pdf_filename = "fixed_device_fraud_dataset.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

# Styles Setup
styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=18, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
section_style = ParagraphStyle('Section', parent=styles['Heading2'], fontSize=13, textColor=colors.HexColor("#2B6CB0"), spaceBefore=12, spaceAfter=8)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16, spaceAfter=10)

# Render Document Elements
story.append(Paragraph("Automated Insurance Claims Directory", title_style))
story.append(Paragraph("Internal Audit Intake Records for Knowledge Extraction.", styles['Italic']))
story.append(Spacer(1, 10))

story.append(Paragraph("Claims Processing Logs", section_style))

for claim in insurance_fraud_data:
    narrative = (
        f"{claim['claim_id']} involves {claim['claimed_amount']}. <br/>"
        f"{claim['claim_id']} records {claim['accident_date']}. <br/>"
        f"{claim['claim_id']} involves {claim['device']}." 
    )
    story.append(Paragraph(narrative, body_style))
    story.append(Spacer(1, 10))



doc.build(story)
print(f"Insurance fraud demo PDF successfully compiled at: {pdf_filename}")
# Out:
# Insurance fraud demo PDF successfully compiled at: fixed_device_fraud_dataset.pdf

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer, Table, TableStyle
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Expanded Mock Dataset (10 Records)
insurance_fraud_data = [
    {"claim_id": "Claim_101", "policyholder": "Policyholder_A", "accident_date": "Date_12_March", "device": "HW_ID_991X", "claimed_amount": "Amount_INR_350000"},
    {"claim_id": "Claim_102", "policyholder": "Policyholder_B", "accident_date": "Date_14_March", "device": "HW_ID_991X", "claimed_amount": "Amount_INR_420000"}, # Ring Anchor
    {"claim_id": "Claim_103", "policyholder": "Policyholder_C", "accident_date": "Date_15_March", "device": "HW_ID_991X", "claimed_amount": "Amount_INR_150000"}, # Ring Anchor
    {"claim_id": "Claim_104", "policyholder": "Policyholder_D", "accident_date": "Date_18_March", "device": "HW_ID_882Y", "claimed_amount": "Amount_INR_220000"},
    {"claim_id": "Claim_105", "policyholder": "Policyholder_E", "accident_date": "Date_19_March", "device": "HW_ID_773Z", "claimed_amount": "Amount_INR_610000"},
    {"claim_id": "Claim_106", "policyholder": "Policyholder_F", "accident_date": "Date_21_March", "device": "HW_ID_114A", "claimed_amount": "Amount_INR_180000"},
    {"claim_id": "Claim_107", "policyholder": "Policyholder_G", "accident_date": "Date_22_March", "device": "HW_ID_225B", "claimed_amount": "Amount_INR_290000"},
    {"claim_id": "Claim_108", "policyholder": "Policyholder_H", "accident_date": "Date_25_March", "device": "HW_ID_336C", "claimed_amount": "Amount_INR_850000"},
    {"claim_id": "Claim_109", "policyholder": "Policyholder_I", "accident_date": "Date_26_March", "device": "HW_ID_447D", "claimed_amount": "Amount_INR_130000"},
    {"claim_id": "Claim_110", "policyholder": "Policyholder_J", "accident_date": "Date_29_March", "device": "HW_ID_558E", "claimed_amount": "Amount_INR_490000"}
]

# 2. Document Setup
pdf_filename = "insurance_10_claims_connected.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=30, leftMargin=30, topMargin=30, bottomMargin=30)
story = []

styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=16, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=16)

story.append(Paragraph("Master Claims Audit Processing Logs", title_style))
story.append(Spacer(1, 10))

# 3. Build Isolated Containers to Fix the Connection Issue
for claim in insurance_fraud_data:
    # Hyper-strict syntax without any sentence-ending punctuation to stop character bleeding
    line1 = f"{claim['claim_id']} involves {claim['claimed_amount']}"
    line2 = f"{claim['claim_id']} records {claim['accident_date']}"
    line3 = f"{claim['claim_id']} involves {claim['device']}"
    
    # Combine into a strict, clear narrative paragraph block
    combined_text = f"{line1} <br/>{line2} <br/>{line3}"
    paragraph_block = Paragraph(combined_text, body_style)
    
    # We wrap the text in an individual Table cell. This adds a structural buffer 
    # in the PDF data layers, forcing your parser to reset its memory for each claim.
    container_table = Table([[paragraph_block]], colWidths=[500])
    container_table.setStyle(TableStyle([
        ('VALIGN', (0,0), (-1,-1), 'TOP'),
        ('BOTTOMPADDING', (0,0), (-1,-1), 12),
        ('TOPPADDING', (0,0), (-1,-1), 12),
    ]))
    
    story.append(container_table)
    story.append(Spacer(1, 10))

doc.build(story)
print(f"Successfully generated 10-record fixed dataset at: {pdf_filename}")
# Out:
# Successfully generated 10-record fixed dataset at: insurance_10_claims_connected.pdf

# %%
import json
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle

# 1. Expanded Master Dataset (10 Profiles)
insurance_fraud_data = [
    {"claim_id": "Claim_101", "device": "HW_ID_991X", "amount": "Amount_INR_350000", "date": "Date_12_March"},
    {"claim_id": "Claim_102", "device": "HW_ID_991X", "amount": "Amount_INR_420000", "date": "Date_14_March"}, # Ring Link 1
    {"claim_id": "Claim_103", "device": "HW_ID_991X", "amount": "Amount_INR_150000", "date": "Date_15_March"}, # Ring Link 2
    {"claim_id": "Claim_104", "device": "HW_ID_882Y", "amount": "Amount_INR_220000", "date": "Date_18_March"},
    {"claim_id": "Claim_105", "device": "HW_ID_773Z", "amount": "Amount_INR_610000", "date": "Date_19_March"},
    {"claim_id": "Claim_106", "device": "HW_ID_114A", "amount": "Amount_INR_180000", "date": "Date_21_March"},
    {"claim_id": "Claim_107", "device": "HW_ID_225B", "amount": "Amount_INR_290000", "date": "Date_22_March"},
    {"claim_id": "Claim_108", "device": "HW_ID_336C", "amount": "Amount_INR_850000", "date": "Date_25_March"},
    {"claim_id": "Claim_109", "device": "HW_ID_447D", "amount": "Amount_INR_130000", "date": "Date_26_March"},
    {"claim_id": "Claim_110", "device": "HW_ID_558E", "amount": "Amount_INR_490000", "date": "Date_29_March"}
]

# 2. PDF Document Setup
pdf_filename = "insurance_unified_10_claims.pdf"
doc = SimpleDocTemplate(pdf_filename, pagesize=letter, rightMargin=40, leftMargin=40, topMargin=40, bottomMargin=40)
story = []

styles = getSampleStyleSheet()
title_style = ParagraphStyle('Title', parent=styles['Heading1'], fontSize=16, textColor=colors.HexColor("#1A365D"), spaceAfter=15)
body_style = ParagraphStyle('Body', parent=styles['BodyText'], fontSize=11, leading=18)

story.append(Paragraph("Unified Claims Audit System Log", title_style))
story.append(Spacer(1, 10))

# 3. Create a Single Continuous Unbroken String
unified_narrative_elements = []

for claim in insurance_fraud_data:
    # Build hyper-strict continuous triples without line breaks or sentence endings
    chunk = (
    f"({claim['claim_id']},HAS_AMOUNT,{claim['amount']}) "
    f"({claim['claim_id']},HAS_DATE,{claim['date']}) "
    f"({claim['claim_id']},USES_DEVICE,{claim['device']}) "
        )
    unified_narrative_elements.append(chunk)

# Join everything with space into ONE single comprehensive paragraph block
final_text_block = " ".join(unified_narrative_elements)

story.append(Paragraph(final_text_block, body_style))

doc.build(story)
print(f"Successfully generated unified 10-claim streaming dataset at: {pdf_filename}")
# Out:
# Successfully generated unified 10-claim streaming dataset at: insurance_unified_10_claims.pdf
